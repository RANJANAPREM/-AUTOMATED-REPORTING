# %%
pip install reportlab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.1 MB/s eta 0:00:00
# ...

# %%
from jinja2 import Environment, FileSystemLoader
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# %%
env = Environment(loader=FileSystemLoader('.'))
# Creating the HTML file
file_html = open("report_template.html", "w")
# Adding the input data to the HTML file
file_html.write('''<html>
<head>
<title>HTML File</title>
</head>
<body>
<h1>Welcome</h1>
<p>Automated Report Generating</p>
</body>
</html>''')
# Saving the data into the HTML file
file_html.close()
template = env.get_template('report_template.html')

# %%
report_data = {
    'title': 'Automated Report',
    'data': 'Alert_data',  # Assuming you have processed sales data
    'date': 'June 2023',
    'generated_by': 'Team 5'
}
report_content = template.render(report_data)

# %%
pdf_file = 'Alert_Management_report.pdf'
pdf_canvas = canvas.Canvas(pdf_file, pagesize=letter)
pdf_canvas.drawString(100, 750, "Automated Report")
pdf_canvas.drawString(100, 700, "Generated by: Team 5")
pdf_canvas.drawString(100, 650, "Date: June 2023")
pdf_canvas.drawString(100, 600, "report_content")
# Rendered content from the template
pdf_canvas.save()

# %%
pip install apscheduler
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 1.0 MB/s eta 0:00:00
# ...

# %%
from apscheduler.schedulers.blocking import BlockingScheduler


def generate_report():
    attachment="https://colab.research.google.com/drive/1mrNITNdy0-48NHDcIZOSJ4kTy-5Cmomm?usp=drive_link"
    scheduler = BlockingScheduler()
    scheduler.add_job(generate_report, 'interval', hours=1)  # Run the script every 24 hours
    scheduler.start()

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

# %%
from google.colab import files

# Upload a file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ebdc0a92-85a1-4f48-af16-4d47e2d4ca07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebdc0a92-85a1-4f48-af16-4d47e2d4ca07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install schedule

# %%
import smtplib
import schedule
import time
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication

def generate_report():
    # Code to generate the report
    report_content = "AUTOMATED REPORT."
    return report_content

def send_email(report_content):
    # Email configuration
    sender_email = 'petbird1234@gmail.com'
    receiver_email = 'sneha070602@gmail.com'
    subject = 'Automated Report'

    # Create the email message
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = subject

    # Attach the report content as plain text
    report_text = MIMEText(report_content, 'plain')
    msg.attach(report_text)

 # PDF file path to attach
    pdf_path = 'FINAL LINK.pdf'

 # Attach the PDF file
    with open(pdf_path, 'rb') as pdf_file:
        pdf_attachment = MIMEApplication(pdf_file.read(), _subtype='pdf')
    pdf_attachment.add_header('Content-Disposition', f'attachment; filename={pdf_path}')
    msg.attach(pdf_attachment)

    # SMTP configuration
    smtp_server = 'smtp.gmail.com'
    smtp_port = 587
    smtp_username = 'petbird1234@gmail.com'
    smtp_password = 'qxguatqqpctjgfcp'

    # Send the email
    with smtplib.SMTP(smtp_server, smtp_port) as server:
        server.starttls()
        server.login(smtp_username, smtp_password)
        server.send_message(msg)

    print('Report generated and emailed.')

# Generate the report
report_content = generate_report()

# Send the email
send_email(report_content)

def generate_report_report(minutes):

  schedule.every(10).minutes.do(generate_report)

  while True:
        schedule.run_pending()
        time.sleep(1)
# Out:
# Report generated and emailed.
